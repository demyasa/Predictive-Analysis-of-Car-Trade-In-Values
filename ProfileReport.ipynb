# %% [markdown]
# ### Install necessary package

# %%
# %pip install ydata_profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# ### Read in dataset

# %%
# Point to data location
path = "./scraper/data/6_23_2025/"
all_files = glob.glob(path + "*.json")

# Read all files into single dataframe
df_list = []
for file in all_files:
    df = pd.read_json(file)
    df_list.append(df)

raw_df = pd.concat(df_list, ignore_index=True) # ignore_index resets index of combined DF to prevent index duplicates
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/dunya/Desktop/Predictive-Analysis-Carmax/ProfileReport.ipynb Cell 6 line 8
#       <a href='vscode-notebook-cell:/Users/dunya/Desktop/Predictive-Analysis-Carmax/ProfileReport.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> df_list = []
#       <a href='vscode-notebook-cell:/Users/dunya/Desktop/Predictive-Analysis-Carmax/ProfileReport.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> for file in all_files:
# ----> <a href='vscode-notebook-cell:/Users/dunya/Desktop/Predictive-Analysis-Carmax/ProfileReport.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     df = pd.read_json(file)
#       <a href='vscode-notebook-cell:/Users/dunya/Desktop/Predictive-Analysis-Carmax/ProfileReport.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>     df_list.append(df)
# ...

# %% [markdown]
# ### Generate Report

# %%
# quick eda
profile = ProfileReport(raw_df, title=f"NewEDA")
profile.to_notebook_iframe()
