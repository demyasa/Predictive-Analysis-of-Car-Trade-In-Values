# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)
import glob
import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read in the Dataset

# %%
# Point to data files location
path = "./scraper/data/6_23_2025/"
all_files = glob.glob(path + "*.json")

# Read all files into single dataframe
df_list = []
for file in all_files:
    df = pd.read_json(file)
    df_list.append(df)

# ignore_index resets index of combined DF to prevent index duplicates
raw_df = pd.concat(df_list, ignore_index=True) 

# Display entire data frame
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Examine and excerpt of data
raw_df.head(5)
# Out:
#    stockNumber                vin  year        make              model  \
# 0     27461478  5NPEG4JA8NH134099  2022     Hyundai             Sonata
# 1     26070459  JTDEPMAE5NJ210260  2022      Toyota            Corolla
# 2     27175122  3GCUDFE80RG128481  2024   Chevrolet     Silverado 1500
# 3     27072297  1V2WE2CA5PC229115  2023  Volkswagen  Atlas Cross Sport
# 4     27386026  58AGZ1B12MU110647  2021       Lexus             ES 350
#
#                body           trim  basePrice  originalPrice  hasPriceDrop  \
# 0          4D Sedan             SE      19998            NaN         False
# 1          4D Sedan             LE      20998            NaN         False
# 2       4D Crew Cab  LT Trail Boss      51998            NaN         False
# 3  4D Sport Utility      SE w/Tech      32998            NaN         False
# 4          4D Sedan        F-Sport      35998            NaN         False
#
#    mileage  storeId storeName storeCity    state stateAbbreviation  distance  \
# 0    56782     7298   Roswell   Roswell  Georgia                GA    2108.0
# 1    33730     7298   Roswell   Roswell  Georgia                GA    2108.0
# 2    58240     7298   Roswell   Roswell  Georgia                GA    2108.0
# 3    15895     7298   Roswell   Roswell  Georgia                GA    2108.0
# 4    26900     7298   Roswell   Roswell  Georgia                GA    2108.0
#
#    averageRating  numberOfReviews  repairPalData  isNewArrival  \
# 0       4.200000                5            NaN         False
# 1       4.500000               22            NaN         False
# 2       5.000000                1            NaN         False
# 3       5.000000                2            NaN         False
# 4       4.333333                6            NaN         False
#
#    isTransferable                                           features  \
# 0            True  [Rear Defroster, Overhead Airbags, Auxiliary A...
# 1            True  [Power Windows, Power Locks, Air Conditioning,...
# 2            True  [Power Locks, Auxiliary Audio Input, AM/FM Ste...
# 3            True  [Alloy Wheels, 20 Inch Plus Wheels, Power Lock...
# 4            True  [Power Windows, Traction Control, ABS Brakes, ...
#
#                                  highlightedFeatures  \
# 0  Rear View Camera,Auxiliary Audio Input,Alloy W...
# 1  Rear View Camera,Auxiliary Audio Input,Overhea...
# 2  Z71 Package,4WD/AWD,Leather Seats,BOSE Sound S...
# 3  Technology Package,Leatherette Seats,Satellite...
# 4  Leatherette Seats,Pioneer Sound System,Parking...
#
#                                           highlights  \
# 0  [singleOwner, warranty, fuelEfficient, advance...
# 1        [warranty, fuelEfficient, advancedFeatures]
# 2      [singleOwner, advancedFeatures, premiumAudio]
# 3  [singleOwner, lowMiles, warranty, advancedFeat...
# 4  [singleOwner, lowMilesPerYear, warranty, advan...
#
#        lastMadeSaleableDate  transferFee            transferTags  \
# 0  2025-06-12T20:56:13.565Z       1999.0  [GeneratedByCps, Paid]
# 1  2025-06-12T20:53:33.311Z       1999.0  [GeneratedByCps, Paid]
# 2  2025-06-20T21:39:32.178Z       1999.0  [GeneratedByCps, Paid]
# 3  2025-05-28T20:50:22.353Z       1999.0  [GeneratedByCps, Paid]
# 4   2025-06-13T20:59:37.45Z       1999.0  [GeneratedByCps, Paid]
#
#      transferText   transferType  minEstimatedTransferDurationInDays  \
# 0  $1999 Shipping  shipping-from                                 9.0
# 1  $1999 Shipping  shipping-from                                 9.0
# 2  $1999 Shipping  shipping-from                                 9.0
# 3  $1999 Shipping  shipping-from                                 9.0
# 4  $1999 Shipping  shipping-from                                 9.0
#
#    maxEstimatedTransferDurationInDays  transferTimesUnavailable exteriorColor  \
# 0                                22.0                     False          Gray
# 1                                22.0                     False          Blue
# 2                                22.0                     False         Black
# 3                                22.0                     False         Black
# 4                                22.0                     False         Black
#
#   interiorColor  normalizedExteriorColor  normalizedInteriorColor  \
# 0          Gray                      NaN                      NaN
# 1         Black                      NaN                      NaN
# 2         Black                      NaN                      NaN
# 3         Black                      NaN                      NaN
# 4           Red                      NaN                      NaN
#
#   transmission  review  numberOfFavorites  isSaleable  isComingSoon  \
# 0    Automatic     NaN                  0        True         False
# 1    Automatic     NaN                  0        True         False
# 2    Automatic     NaN                  0        True         False
# 3    Automatic     NaN                  0        True         False
# 4    Automatic     NaN                  0        True         False
#
#    isReserved  mpgCity  mpgHighway  originalBatteryRangeInMiles  cylinders  \
# 0       False     28.0        38.0                          NaN          4
# 1       False     30.0        38.0                          NaN          4
# 2       False     23.0        27.0                          NaN          6
# 3       False     18.0        24.0                          NaN          6
# 4       False     22.0        31.0                          NaN          6
#
#           driveTrain engineType  fuelType  horsepower  horsepowerRpm  \
# 0  Front Wheel Drive        Gas       NaN       191.0         6100.0
# 1  Front Wheel Drive        Gas       NaN       139.0         6100.0
# 2   Four Wheel Drive     Diesel       NaN       305.0         3750.0
# 3  Front Wheel Drive        Gas       NaN       276.0         6200.0
# 4  Front Wheel Drive        Gas       NaN       302.0         6600.0
#
#   engineSize  engineTorque  engineTorqueRpm  \
# 0       2.5L         181.0           4000.0
# 1       1.8L         126.0           3900.0
# 2       3.0L         495.0           2750.0
# 3       3.6L         266.0           3600.0
# 4       3.5L         267.0           4700.0
#
#                                 priorUseDescriptions  isAvailableToTransact  \
# 0  [{'id': 20, 'name': 'Leased Vehicle', 'descrip...                   True
# 1  [{'id': 10, 'name': 'Fleet', 'description': 'T...                   True
# 2                                                 []                   True
# 3  [{'id': 10, 'name': 'Fleet', 'description': 'T...                   True
# 4  [{'id': 20, 'name': 'Leased Vehicle', 'descrip...                   True
#
#    recommendationType  bestFinanceDecision  \
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
#                                                store  featureScore  \
# 0  {'id': 7298, 'name': 'Roswell', 'city': None, ...           3.0
# 1  {'id': 7298, 'name': 'Roswell', 'city': None, ...           7.0
# 2  {'id': 7298, 'name': 'Roswell', 'city': None, ...          10.0
# 3  {'id': 7298, 'name': 'Roswell', 'city': None, ...           5.0
# 4  {'id': 7298, 'name': 'Roswell', 'city': None, ...           7.0
#
#    vehicleSize                            packages  types series  isSavedCar  \
# 0          NaN                                  []    NaN   None       False
# 1          NaN                                  []    NaN   None       False
# 2          NaN  [Convenience Package, Z71 Package]    NaN   None       False
# 3          NaN                [Technology Package]    NaN   None       False
# 4          NaN                                  []    NaN     ES       False
#
#                                         heroImageUrl  heroThumbnailImageUrl  \
# 0  https://img2.carmax.com/assets/27461478/hero.j...                    NaN
# 1  https://img2.carmax.com/assets/26070459/hero.j...                    NaN
# 2  https://img2.carmax.com/assets/27175122/hero.j...                    NaN
# 3  https://img2.carmax.com/assets/27072297/hero.j...                    NaN
# 4  https://img2.carmax.com/assets/27386026/hero.j...                    NaN
#
#    isEVTaxCreditEligible
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %% [markdown]
# ### Drop Duplicate Rows

# %%
# Make a copy of the original dataframe
df = raw_df.copy()

# Check rows with duplicate VINS and drop
df = df.drop_duplicates(subset=['vin'], keep='first')

# %% [markdown]
# ### Convert Engine Size to Numeric Datatype

# %%
# Convert Engine Size into a numeric feature by removing the L and changing datatype
df['engineSize'] = df['engineSize'].str.replace('L', '', regex=False)
df['engineSize'] = pd.to_numeric(df['engineSize'])

print(df['engineSize'].dtype)
# Out:
# float64

# %% [markdown]
# ### Remove Unnecessary Columns Based on Previous Analyses

# %%
# Store irrelevant features into an array
irrelevant_features = [
    'stockNumber', 'hasPriceDrop', 'distance', 'isNewArrival',
    'isTransferable', 'lastMadeSaleableDate', 'transferFee', 'transferTags',
    'transferText', 'transferType', 'minEstimatedTransferDurationInDays', 'maxEstimatedTransferDurationInDays',
    'transferTimesUnavailable', 'isSaleable', 'isComingSoon', 'isReserved',
    'isAvailableToTransact', 'recommendationType', 'bestFinanceDecision', 'isSavedCar',
    'heroImageUrl', 'heroThumbnailImageUrl'
]

# Leave only state to represent location
location_features = [
    'store', 'storeId', 'storeName', 'storeCity', 'stateAbbreviation'
]

# Remove missing values features
missing_value_features = [
    'review', 'repairPalData', 'types', 'vehicleSize', 
    'normalizedExteriorColor', 'normalizedInteriorColor', 'fuelType',
    'originalBatteryRangeInMiles', 'originalPrice', 'series'
]

# Drop features being analyzed in a different file
complex_features = [
    'features', 'highlightedFeatures', 'highlights',
    'priorUseDescriptions', 'packages'
]

# Drop irrelevant feature arrays defined above
df = df.drop(columns = irrelevant_features, axis = 1)
df = df.drop(columns = location_features, axis = 1)
df = df.drop(columns = missing_value_features, axis = 1)
df = df.drop(columns = complex_features, axis = 1)
df = df.drop(columns = ['isEVTaxCreditEligible'], axis = 1)
df = df.drop(columns = ['numberOfFavorites'], axis = 1)

# Remove missing value rows for the following features
missing_value_rows = [
    'interiorColor', 'exteriorColor'
]
df.dropna(subset=missing_value_rows, how='any',inplace=True)

# Leave predictable missing value rows
# 'driveTrain', 'engineSize', 'engineType', 'body', 'transmission'

# # Other missing value rows
# missing_value_rows_2 = [
#     'engineTorqueRpm', 'horsepowerRpm', 'engineTorque', 'horsepower', 
#     'mpgCity', 'mpgHighway', 'engineType'
# ]

# df.dropna(subset=missing_value_rows_2, how='any', inplace=True)

print("DataFrame Shape:", df.shape)
# Out:
# DataFrame Shape: (86027, 25)

# %%
# Use method to display a list of missing values and their percentages

# credit: https://www.kaggle.com/willkoehrsen/start-here-a-gentle-introduction. 

def missing_values_table(df):
    # Total missing values
    mis_val = df.isnull().sum()
    
    # Percentage of missing values
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    
    # Make a table with the results
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    
    # Rename the columns
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    
    # Sort the table by percentage of missing descending
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(2)
    
    # Print some summary information
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    
    # Return the dataframe with missing information
    return mis_val_table_ren_columns

# %%
# Apply missing values table method on the dataframe
missing_vals = missing_values_table(df)
missing_vals
# Out:
# Your selected dataframe has 25 columns.
# There are 12 columns that have missing values.
#                  Missing Values  % of Total Values
# featureScore               8761              10.18
# trim                       7344               8.54
# engineTorqueRpm            5839               6.79
# horsepowerRpm              5071               5.89
# engineTorque               4543               5.28
# horsepower                 4365               5.07
# mpgCity                    3441               4.00
# mpgHighway                 3438               4.00
# driveTrain                  264               0.31
# engineSize                   10               0.01
# engineType                    2               0.00
# body                          1               0.00

# %% [markdown]
# ### Impute Feature Scores and Trims

# %%
# Regressor for Numerical Values
# Classifier for Categorical Values
from lightgbm import LGBMRegressor, LGBMClassifier

# %%
# Display columns in df with missing vals
cols_with_nans = [x for x in df if df[x].isnull().sum() > 0]
cols_with_nans
# Out:
# ['body',
#  'trim',
#  'mpgCity',
#  'mpgHighway',
#  'driveTrain',
#  'engineType',
#  'horsepower',
#  'horsepowerRpm',
#  'engineSize',
#  'engineTorque',
#  'engineTorqueRpm',
#  'featureScore']

# %%
# Divide into categorical and numeric columns
num_cols = [col for col in df[cols_with_nans].select_dtypes(exclude='O')]
cat_cols = [col for col in df[cols_with_nans].select_dtypes(include='O')]

print("Numeric Columns: \n", num_cols)
print("Categorical Columns: \n", cat_cols)
# Out:
# Numeric Columns:
#  ['mpgCity', 'mpgHighway', 'horsepower', 'horsepowerRpm', 'engineSize', 'engineTorque', 'engineTorqueRpm', 'featureScore']
# Categorical Columns:
#  ['body', 'trim', 'driveTrain', 'engineType']

# %%
def factorize(data):
    # Factorize categorical data so its represented as integers
    for cat_col in data.select_dtypes(include='O'):
        data[cat_col] = pd.factorize(data[cat_col])[0]
    return data

def create_splits(data, col):
    # Train Test split on null values present
    train = data[data['is_nan'] == 0]
    test = data[data['is_nan'] == 1]
    X_train = train.drop([col, 'is_nan'], axis=1)
    y_train = train[col]
    X_test = test.drop([col, 'is_nan'], axis=1)
    return X_train, y_train, X_test

def train_predict(mode, X_train, y_train, X_test):
    if mode == 'regression':
        model = LGBMRegressor()
    else :
        model = LGBMClassifier()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return y_pred


def impute_missing(df, col_list, mode):
    for col in col_list:
        print("Column Examined: ", col)
        if df[col].isnull().sum() > int(len(df)/2):
            df.drop(col, axis=1, inplace=True)
            print(f'Dropped {col} because it had over 50% missing values')
        else:
            data = df.copy()
            # Reset Indexes
            data = data.reset_index(drop=True)
            nan_ixs = np.where(data[col].isna())[0]
            data['is_nan'] = 0
            data.loc[nan_ixs, 'is_nan'] = 1
            X = data.drop([col], axis=1)
            y = data[col]
            X = factorize(X)
            data = X.join(y)
            X_train, y_train, X_test = create_splits(data, col)
            y_pred = train_predict(mode, X_train, y_train, X_test)
            print("Predictions: \n", y_pred)
            # Include predicted values in the indices of missing column
            df = df.reset_index(drop=True)
            df.loc[nan_ixs, col] = y_pred
            # df = data
    return df

df = impute_missing(df, num_cols, 'regression')
df = impute_missing(df, cat_cols, 'classification')
# Out:
# Column Examined:  mpgCity
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001517 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2247
# [LightGBM] [Info] Number of data points in the train set: 82586, number of used features: 24
# [LightGBM] [Info] Start training from score 23.494236
# Predictions:
#  [22.2098031  27.69997408 27.27459943 ... 26.88871557 27.92269495
#  17.32211575]
# Column Examined:  mpgHighway
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001196 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2250
# [LightGBM] [Info] Number of data points in the train set: 82589, number of used features: 24
# [LightGBM] [Info] Start training from score 30.076705
# Predictions:
#  [28.67444747 29.43458521 32.77968001 ... 32.76997261 29.61278879
#  23.31564248]
# Column Examined:  horsepower
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001087 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2254
# [LightGBM] [Info] Number of data points in the train set: 81662, number of used features: 24
# [LightGBM] [Info] Start training from score 232.488122
# Predictions:
#  [265.15861071 220.48693576 212.9591719  ... 196.68810717 257.04064626
#  212.23183928]
# Column Examined:  horsepowerRpm
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001405 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2393
# [LightGBM] [Info] Number of data points in the train set: 80956, number of used features: 24
# [LightGBM] [Info] Start training from score 5870.814455
# Predictions:
#  [6101.34216555 6006.14294042 5917.76585942 ... 6055.49783705 5405.35635605
#  5926.16928236]
# Column Examined:  engineSize
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001403 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2712
# [LightGBM] [Info] Number of data points in the train set: 86017, number of used features: 24
# [LightGBM] [Info] Start training from score 2.569194
# Predictions:
#  [2.37196782 3.47761968 2.77100049 1.87857434 2.68400748 0.00415498
#  2.00261704 2.0073826  2.0132203  1.85592329]
# Column Examined:  engineTorque
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001095 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2362
# [LightGBM] [Info] Number of data points in the train set: 81484, number of used features: 24
# [LightGBM] [Info] Start training from score 235.178759
# Predictions:
#  [278.58561182 239.91547801 216.39061411 ... 219.8411516  308.96896205
#  239.59693701]
# Column Examined:  engineTorqueRpm
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2375
# [LightGBM] [Info] Number of data points in the train set: 80188, number of used features: 24
# [LightGBM] [Info] Start training from score 3443.393151
# Predictions:
#  [3497.50406598 2475.91563305 2164.71977095 ... 1642.54515706 3733.27468466
#  2586.3944435 ]
# Column Examined:  featureScore
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001239 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2903
# [LightGBM] [Info] Number of data points in the train set: 77266, number of used features: 24
# [LightGBM] [Info] Start training from score 6.729765
# Predictions:
#  [3.88599225 5.06262929 4.11094098 ... 6.94247284 6.90094958 7.34446212]
# Column Examined:  body
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001282 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3149
# [LightGBM] [Info] Number of data points in the train set: 86026, number of used features: 24
# [LightGBM] [Info] Start training from score -4.593912
# [LightGBM] [Info] Start training from score -3.882541
# [LightGBM] [Info] Start training from score -9.752967
# [LightGBM] [Info] Start training from score -5.724050
# [LightGBM] [Info] Start training from score -6.180621
# [LightGBM] [Info] Start training from score -5.919987
# [LightGBM] [Info] Start training from score -8.226911
# [LightGBM] [Info] Start training from score -7.142897
# [LightGBM] [Info] Start training from score -7.219270
# [LightGBM] [Info] Start training from score -8.417966
# [LightGBM] [Info] Start training from score -7.865897
# [LightGBM] [Info] Start training from score -8.964510
# [LightGBM] [Info] Start training from score -7.512257
# [LightGBM] [Info] Start training from score -2.555831
# [LightGBM] [Info] Start training from score -4.331547
# [LightGBM] [Info] Start training from score -9.059820
# [LightGBM] [Info] Start training from score -3.363733
# [LightGBM] [Info] Start training from score -5.403980
# [LightGBM] [Info] Start training from score -4.235514
# [LightGBM] [Info] Start training from score -1.500052
# [LightGBM] [Info] Start training from score -0.553162
# [LightGBM] [Info] Start training from score -4.171729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Predictions:
#  ['4D Crew Cab']
# Column Examined:  trim
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001196 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2893
# [LightGBM] [Info] Number of data points in the train set: 78683, number of used features: 24
# [LightGBM] [Info] Start training from score -8.182140
# [LightGBM] [Info] Start training from score -6.554684
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -8.500594
# [LightGBM] [Info] Start training from score -9.327272
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.327272
# [LightGBM] [Info] Start training from score -9.193741
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -7.212739
# [LightGBM] [Info] Start training from score -8.565132
# [LightGBM] [Info] Start training from score -5.228177
# [LightGBM] [Info] Start training from score -7.114299
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -8.708233
# [LightGBM] [Info] Start training from score -8.634125
# [LightGBM] [Info] Start training from score -8.565132
# [LightGBM] [Info] Start training from score -7.535513
# [LightGBM] [Info] Start training from score -8.875287
# [LightGBM] [Info] Start training from score -8.565132
# [LightGBM] [Info] Start training from score -6.269236
# [LightGBM] [Info] Start training from score -8.970597
# [LightGBM] [Info] Start training from score -7.905887
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -8.708233
# [LightGBM] [Info] Start training from score -6.955694
# [LightGBM] [Info] Start training from score -5.776014
# [LightGBM] [Info] Start training from score -8.382811
# [LightGBM] [Info] Start training from score -6.502498
# [LightGBM] [Info] Start training from score -6.628792
# [LightGBM] [Info] Start training from score -6.269236
# [LightGBM] [Info] Start training from score -7.212739
# [LightGBM] [Info] Start training from score -8.634125
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -8.137688
# [LightGBM] [Info] Start training from score -7.871985
# [LightGBM] [Info] Start training from score -8.015086
# [LightGBM] [Info] Start training from score -6.511008
# [LightGBM] [Info] Start training from score -5.796719
# [LightGBM] [Info] Start training from score -5.474090
# [LightGBM] [Info] Start training from score -8.277450
# [LightGBM] [Info] Start training from score -6.878733
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.193741
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -8.182140
# [LightGBM] [Info] Start training from score -8.708233
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.193741
# [LightGBM] [Info] Start training from score -5.678471
# [LightGBM] [Info] Start training from score -7.717834
# [LightGBM] [Info] Start training from score -7.940978
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -8.634125
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -8.500594
# [LightGBM] [Info] Start training from score -8.439969
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -8.970597
# [LightGBM] [Info] Start training from score -9.663744
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -9.663744
# [LightGBM] [Info] Start training from score -7.381362
# [LightGBM] [Info] Start training from score -8.228660
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.663744
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.327272
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -7.807446
# [LightGBM] [Info] Start training from score -9.193741
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -8.788276
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.075958
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -8.228660
# [LightGBM] [Info] Start training from score -7.423035
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -6.762323
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.075958
# [LightGBM] [Info] Start training from score -6.519592
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -8.228660
# [LightGBM] [Info] Start training from score -7.230131
# [LightGBM] [Info] Start training from score -8.708233
# [LightGBM] [Info] Start training from score -6.903735
# [LightGBM] [Info] Start training from score -7.940978
# [LightGBM] [Info] Start training from score -7.284198
# [LightGBM] [Info] Start training from score -8.182140
# [LightGBM] [Info] Start training from score -7.511982
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -8.634125
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.663744
# [LightGBM] [Info] Start training from score -9.663744
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -9.663744
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -9.481423
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -9.481423
# [LightGBM] [Info] Start training from score -5.562755
# [LightGBM] [Info] Start training from score -9.075958
# [LightGBM] [Info] Start training from score -8.500594
# [LightGBM] [Info] Start training from score -9.193741
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -7.302890
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.193741
# [LightGBM] [Info] Start training from score -7.068490
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.663744
# [LightGBM] [Info] Start training from score -9.075958
# [LightGBM] [Info] Start training from score -8.228660
# [LightGBM] [Info] Start training from score -9.663744
# [LightGBM] [Info] Start training from score -9.075958
# [LightGBM] [Info] Start training from score -8.015086
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -9.481423
# [LightGBM] [Info] Start training from score -9.327272
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -9.075958
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -6.784546
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -5.879555
# [LightGBM] [Info] Start training from score -5.376029
# [LightGBM] [Info] Start training from score -8.970597
# [LightGBM] [Info] Start training from score -6.807274
# [LightGBM] [Info] Start training from score -7.511982
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -9.481423
# [LightGBM] [Info] Start training from score -7.381362
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -8.439969
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.327272
# [LightGBM] [Info] Start training from score -6.042074
# [LightGBM] [Info] Start training from score -8.228660
# [LightGBM] [Info] Start training from score -8.875287
# [LightGBM] [Info] Start training from score -5.767851
# [LightGBM] [Info] Start training from score -8.439969
# [LightGBM] [Info] Start training from score -9.481423
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.193741
# [LightGBM] [Info] Start training from score -9.481423
# [LightGBM] [Info] Start training from score -9.886888
# [LightGBM] [Info] Start training from score -9.075958
# [LightGBM] [Info] Start training from score -9.327272
# [LightGBM] [Info] Start training from score -8.708233
# [LightGBM] [Info] Start training from score -8.182140
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -7.807446
# [LightGBM] [Info] Start training from score -7.977346
# [LightGBM] [Info] Start training from score -9.481423
# [LightGBM] [Info] Start training from score -10.580035
# [LightGBM] [Info] Start training from score -9.193741
# [LightGBM] [Info] Start training from score -10.174570
# [LightGBM] [Info] Start training from score -11.273182
# [LightGBM] [Info] Start training from score -8.708233
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Predictions:
#  ['TRD Sport' 'SV' 'SV' ... 'SV' 'XLT' 'SV']
# Column Examined:  driveTrain
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001359 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3157
# [LightGBM] [Info] Number of data points in the train set: 85763, number of used features: 24
# [LightGBM] [Info] Start training from score -1.104565
# [LightGBM] [Info] Start training from score -1.984251
# [LightGBM] [Info] Start training from score -0.850420
# [LightGBM] [Info] Start training from score -2.264077
# Predictions:
#  ['Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Four Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Rear Wheel Drive'
#  'Rear Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'All Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'All Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'All Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Rear Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'All Wheel Drive' 'All Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Rear Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Four Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Four Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive']
# Column Examined:  engineType
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001316 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3163
# [LightGBM] [Info] Number of data points in the train set: 86025, number of used features: 24
# [LightGBM] [Info] Start training from score -4.907195
# [LightGBM] [Info] Start training from score -3.701337
# [LightGBM] [Info] Start training from score -0.088042
# [LightGBM] [Info] Start training from score -3.251666
# [LightGBM] [Info] Start training from score -4.306218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Predictions:
#  ['Gas' 'Gas']

# %%
missing_vals_2 = missing_values_table(df)
missing_vals_2

# df.head()
# Out:
# Your selected dataframe has 25 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
df.to_csv('imputed_data.csv', index=False)
