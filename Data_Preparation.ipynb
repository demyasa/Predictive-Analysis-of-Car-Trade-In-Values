# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)
import glob
import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read in the Dataset

# %%
# Point to data files location
path = "./scraper/data/6_23_2025/"
all_files = glob.glob(path + "*.json")

# Read all files into single dataframe
df_list = []
for file in all_files:
    df = pd.read_json(file)
    df_list.append(df)

# ignore_index resets index of combined DF to prevent index duplicates
raw_df = pd.concat(df_list, ignore_index=True) 

# Display entire data frame
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Examine and excerpt of data
raw_df.head(5)
# Out:
#    stockNumber                vin  year        make              model  \
# 0     27461478  5NPEG4JA8NH134099  2022     Hyundai             Sonata
# 1     26070459  JTDEPMAE5NJ210260  2022      Toyota            Corolla
# 2     27175122  3GCUDFE80RG128481  2024   Chevrolet     Silverado 1500
# 3     27072297  1V2WE2CA5PC229115  2023  Volkswagen  Atlas Cross Sport
# 4     27386026  58AGZ1B12MU110647  2021       Lexus             ES 350
#
#                body           trim  basePrice  originalPrice  hasPriceDrop  \
# 0          4D Sedan             SE      19998            NaN         False
# 1          4D Sedan             LE      20998            NaN         False
# 2       4D Crew Cab  LT Trail Boss      51998            NaN         False
# 3  4D Sport Utility      SE w/Tech      32998            NaN         False
# 4          4D Sedan        F-Sport      35998            NaN         False
#
#    mileage  storeId storeName storeCity    state stateAbbreviation  distance  \
# 0    56782     7298   Roswell   Roswell  Georgia                GA    2108.0
# 1    33730     7298   Roswell   Roswell  Georgia                GA    2108.0
# 2    58240     7298   Roswell   Roswell  Georgia                GA    2108.0
# 3    15895     7298   Roswell   Roswell  Georgia                GA    2108.0
# 4    26900     7298   Roswell   Roswell  Georgia                GA    2108.0
#
#    averageRating  numberOfReviews  repairPalData  isNewArrival  \
# 0       4.200000                5            NaN         False
# 1       4.500000               22            NaN         False
# 2       5.000000                1            NaN         False
# 3       5.000000                2            NaN         False
# 4       4.333333                6            NaN         False
#
#    isTransferable                                           features  \
# 0            True  [Rear Defroster, Overhead Airbags, Auxiliary A...
# 1            True  [Power Windows, Power Locks, Air Conditioning,...
# 2            True  [Power Locks, Auxiliary Audio Input, AM/FM Ste...
# 3            True  [Alloy Wheels, 20 Inch Plus Wheels, Power Lock...
# 4            True  [Power Windows, Traction Control, ABS Brakes, ...
#
#                                  highlightedFeatures  \
# 0  Rear View Camera,Auxiliary Audio Input,Alloy W...
# 1  Rear View Camera,Auxiliary Audio Input,Overhea...
# 2  Z71 Package,4WD/AWD,Leather Seats,BOSE Sound S...
# 3  Technology Package,Leatherette Seats,Satellite...
# 4  Leatherette Seats,Pioneer Sound System,Parking...
#
#                                           highlights  \
# 0  [singleOwner, warranty, fuelEfficient, advance...
# 1        [warranty, fuelEfficient, advancedFeatures]
# 2      [singleOwner, advancedFeatures, premiumAudio]
# 3  [singleOwner, lowMiles, warranty, advancedFeat...
# 4  [singleOwner, lowMilesPerYear, warranty, advan...
#
#        lastMadeSaleableDate  transferFee            transferTags  \
# 0  2025-06-12T20:56:13.565Z       1999.0  [GeneratedByCps, Paid]
# 1  2025-06-12T20:53:33.311Z       1999.0  [GeneratedByCps, Paid]
# 2  2025-06-20T21:39:32.178Z       1999.0  [GeneratedByCps, Paid]
# 3  2025-05-28T20:50:22.353Z       1999.0  [GeneratedByCps, Paid]
# 4   2025-06-13T20:59:37.45Z       1999.0  [GeneratedByCps, Paid]
#
#      transferText   transferType  minEstimatedTransferDurationInDays  \
# 0  $1999 Shipping  shipping-from                                 9.0
# 1  $1999 Shipping  shipping-from                                 9.0
# 2  $1999 Shipping  shipping-from                                 9.0
# 3  $1999 Shipping  shipping-from                                 9.0
# 4  $1999 Shipping  shipping-from                                 9.0
#
#    maxEstimatedTransferDurationInDays  transferTimesUnavailable exteriorColor  \
# 0                                22.0                     False          Gray
# 1                                22.0                     False          Blue
# 2                                22.0                     False         Black
# 3                                22.0                     False         Black
# 4                                22.0                     False         Black
#
#   interiorColor  normalizedExteriorColor  normalizedInteriorColor  \
# 0          Gray                      NaN                      NaN
# 1         Black                      NaN                      NaN
# 2         Black                      NaN                      NaN
# 3         Black                      NaN                      NaN
# 4           Red                      NaN                      NaN
#
#   transmission  review  numberOfFavorites  isSaleable  isComingSoon  \
# 0    Automatic     NaN                  0        True         False
# 1    Automatic     NaN                  0        True         False
# 2    Automatic     NaN                  0        True         False
# 3    Automatic     NaN                  0        True         False
# 4    Automatic     NaN                  0        True         False
#
#    isReserved  mpgCity  mpgHighway  originalBatteryRangeInMiles  cylinders  \
# 0       False     28.0        38.0                          NaN          4
# 1       False     30.0        38.0                          NaN          4
# 2       False     23.0        27.0                          NaN          6
# 3       False     18.0        24.0                          NaN          6
# 4       False     22.0        31.0                          NaN          6
#
#           driveTrain engineType  fuelType  horsepower  horsepowerRpm  \
# 0  Front Wheel Drive        Gas       NaN       191.0         6100.0
# 1  Front Wheel Drive        Gas       NaN       139.0         6100.0
# 2   Four Wheel Drive     Diesel       NaN       305.0         3750.0
# 3  Front Wheel Drive        Gas       NaN       276.0         6200.0
# 4  Front Wheel Drive        Gas       NaN       302.0         6600.0
#
#   engineSize  engineTorque  engineTorqueRpm  \
# 0       2.5L         181.0           4000.0
# 1       1.8L         126.0           3900.0
# 2       3.0L         495.0           2750.0
# 3       3.6L         266.0           3600.0
# 4       3.5L         267.0           4700.0
#
#                                 priorUseDescriptions  isAvailableToTransact  \
# 0  [{'id': 20, 'name': 'Leased Vehicle', 'descrip...                   True
# 1  [{'id': 10, 'name': 'Fleet', 'description': 'T...                   True
# 2                                                 []                   True
# 3  [{'id': 10, 'name': 'Fleet', 'description': 'T...                   True
# 4  [{'id': 20, 'name': 'Leased Vehicle', 'descrip...                   True
#
#    recommendationType  bestFinanceDecision  \
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
#                                                store  featureScore  \
# 0  {'id': 7298, 'name': 'Roswell', 'city': None, ...           3.0
# 1  {'id': 7298, 'name': 'Roswell', 'city': None, ...           7.0
# 2  {'id': 7298, 'name': 'Roswell', 'city': None, ...          10.0
# 3  {'id': 7298, 'name': 'Roswell', 'city': None, ...           5.0
# 4  {'id': 7298, 'name': 'Roswell', 'city': None, ...           7.0
#
#    vehicleSize                            packages  types series  isSavedCar  \
# 0          NaN                                  []    NaN   None       False
# 1          NaN                                  []    NaN   None       False
# 2          NaN  [Convenience Package, Z71 Package]    NaN   None       False
# 3          NaN                [Technology Package]    NaN   None       False
# 4          NaN                                  []    NaN     ES       False
#
#                                         heroImageUrl  heroThumbnailImageUrl  \
# 0  https://img2.carmax.com/assets/27461478/hero.j...                    NaN
# 1  https://img2.carmax.com/assets/26070459/hero.j...                    NaN
# 2  https://img2.carmax.com/assets/27175122/hero.j...                    NaN
# 3  https://img2.carmax.com/assets/27072297/hero.j...                    NaN
# 4  https://img2.carmax.com/assets/27386026/hero.j...                    NaN
#
#    isEVTaxCreditEligible
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %% [markdown]
# ### Drop Duplicate Rows

# %%
# Make a copy of the original dataframe
df = raw_df.copy()

# Check rows with duplicate VINS and drop
df = df.drop_duplicates(subset=['vin'], keep='first')

# %% [markdown]
# ### Remove Unnecessary Columns Based on Previous Analyses

# %%
# Store irrelevant features into an array
irrelevant_features = [
    'stockNumber', 'hasPriceDrop', 'distance', 'isNewArrival',
    'isTransferable', 'lastMadeSaleableDate', 'transferFee', 'transferTags',
    'transferText', 'transferType', 'minEstimatedTransferDurationInDays', 'maxEstimatedTransferDurationInDays',
    'transferTimesUnavailable', 'isSaleable', 'isComingSoon', 'isReserved',
    'isAvailableToTransact', 'recommendationType', 'bestFinanceDecision', 'isSavedCar',
    'heroImageUrl', 'heroThumbnailImageUrl'
]

# Leave only state to represent location
location_features = [
    'store', 'storeId', 'storeName', 'storeCity', 'stateAbbreviation'
]

# Remove missing values features
missing_value_features = [
    'review', 'repairPalData', 'types', 'vehicleSize', 
    'normalizedExteriorColor', 'normalizedInteriorColor', 'fuelType',
    'originalBatteryRangeInMiles', 'originalPrice', 'series'
]

# Drop features being analyzed in a different file
complex_features = [
    'features', 'highlightedFeatures', 'highlights',
    'priorUseDescriptions', 'packages'
]

# Drop irrelevant feature arrays defined above
df = df.drop(columns = irrelevant_features, axis = 1)
df = df.drop(columns = location_features, axis = 1)
df = df.drop(columns = missing_value_features, axis = 1)
df = df.drop(columns = complex_features, axis = 1)
df = df.drop(columns = ['isEVTaxCreditEligible'], axis = 1)
df = df.drop(columns = ['numberOfFavorites'], axis = 1)

# Remove missing value rows for the following features
missing_value_rows = [
    'driveTrain', 'interiorColor', 'exteriorColor', 'engineSize', 'engineType', 'body', 'transmission'
]

# Remove missing value rows for the following features
missing_value_rows_2 = [
    'engineTorqueRpm', 'horsepowerRpm', 'engineTorque', 'horsepower', 
    'mpgCity', 'mpgHighway', 'engineType'
]

df.dropna(subset=missing_value_rows, how='any',inplace=True)
df.dropna(subset=missing_value_rows_2, how='any', inplace=True)

print("DataFrame Shape:", df.shape)
# Out:
# DataFrame Shape: (79112, 25)

# %%
# Use method to display a list of missing values and their percentages

# credit: https://www.kaggle.com/willkoehrsen/start-here-a-gentle-introduction. 

def missing_values_table(df):
    # Total missing values
    mis_val = df.isnull().sum()
    
    # Percentage of missing values
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    
    # Make a table with the results
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    
    # Rename the columns
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    
    # Sort the table by percentage of missing descending
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(2)
    
    # Print some summary information
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    
    # Return the dataframe with missing information
    return mis_val_table_ren_columns

# %%
# Apply missing values table method on the dataframe
missing_vals = missing_values_table(df)
missing_vals
# Out:
# Your selected dataframe has 25 columns.
# There are 2 columns that have missing values.
#               Missing Values  % of Total Values
# featureScore            7931              10.03
# trim                    6863               8.68

# %% [markdown]
# ### Impute Feature Scores and Trims

# %% [markdown]
# ### Can potentially keep the data in the missing_value_rows and missing_value_rows_2 arrays and impute them using the LGBMRegressor as well

# %%
# Regressor for Numerical Values
# Classifier for Categorical Values
from lightgbm import LGBMRegressor, LGBMClassifier

# %%
# Display columns in df with missing vals
cols_with_nans = [x for x in df if df[x].isnull().sum() > 0]
cols_with_nans
# Out:
# ['trim', 'featureScore']

# %%
# Divide into categorical and numeric columns
num_cols = [col for col in df[cols_with_nans].select_dtypes(exclude='O')]
cat_cols = [col for col in df[cols_with_nans].select_dtypes(include='O')]

cat_cols
# Out:
# ['trim']

# %%
def factorize(data):
    # Factorize categorical data so its represented as integers
    for cat_col in data.select_dtypes(include='O'):
        data[cat_col] = pd.factorize(data[cat_col])[0]
    return data

def create_splits(data, col):
    # Train Test split on null values present
    train = data[data['is_nan'] == 0]
    test = data[data['is_nan'] == 1]
    X_train = train.drop([col, 'is_nan'], axis=1)
    y_train = train[col]
    X_test = test.drop([col, 'is_nan'], axis=1)
    return X_train, y_train, X_test

def train_predict(mode, X_train, y_train, X_test):
    if mode == 'regression':
        model = LGBMRegressor()
    else :
        model = LGBMClassifier()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return y_pred


def impute_missing(df, col_list, mode):
    for col in col_list:
        print("Column Examined: ", col)
        if df[col].isnull().sum() > int(len(df)/2):
            df.drop(col, axis=1, inplace=True)
            print(f'Dropped {col} because it had over 50% missing values')
        else:
            data = df.copy()
            # Reset Indexes
            data = data.reset_index(drop=True)
            nan_ixs = np.where(data[col].isna())[0]
            data['is_nan'] = 0
            data.loc[nan_ixs, 'is_nan'] = 1
            X = data.drop([col], axis=1)
            y = data[col]
            X = factorize(X)
            # print("X VARIABLE:", X)
            data = X.join(y)
            X_train, y_train, X_test = create_splits(data, col)
            y_pred = train_predict(mode, X_train, y_train, X_test)
            # Include predicted values in the indices of missing column
            df = df.reset_index(drop=True)
            df.loc[nan_ixs, col] = y_pred
            # df = data
    return df

df = impute_missing(df, num_cols, 'regression')
df = impute_missing(df, cat_cols, 'classification')
# Out:
# Column Examined:  featureScore
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2256
# [LightGBM] [Info] Number of data points in the train set: 71181, number of used features: 24
# [LightGBM] [Info] Start training from score 6.690901
# Column Examined:  trim
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001138 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2273
# [LightGBM] [Info] Number of data points in the train set: 72249, number of used features: 24
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -6.469375
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.127431
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -5.152392
# [LightGBM] [Info] Start training from score -7.028991
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -8.548816
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -7.450204
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -6.183927
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -7.820578
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -6.870386
# [LightGBM] [Info] Start training from score -5.698936
# [LightGBM] [Info] Start training from score -8.297502
# [LightGBM] [Info] Start training from score -6.417189
# [LightGBM] [Info] Start training from score -6.543483
# [LightGBM] [Info] Start training from score -6.183927
# [LightGBM] [Info] Start training from score -7.127431
# [LightGBM] [Info] Start training from score -8.548816
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.052380
# [LightGBM] [Info] Start training from score -7.786676
# [LightGBM] [Info] Start training from score -7.929777
# [LightGBM] [Info] Start training from score -6.425700
# [LightGBM] [Info] Start training from score -5.711410
# [LightGBM] [Info] Start training from score -5.388781
# [LightGBM] [Info] Start training from score -8.192141
# [LightGBM] [Info] Start training from score -6.793425
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -5.707235
# [LightGBM] [Info] Start training from score -7.632526
# [LightGBM] [Info] Start training from score -7.855669
# [LightGBM] [Info] Start training from score -8.548816
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -7.296053
# [LightGBM] [Info] Start training from score -8.143351
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -7.722138
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.143351
# [LightGBM] [Info] Start training from score -7.337726
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -6.911208
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -6.677014
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.243435
# [LightGBM] [Info] Start training from score -7.162522
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -6.818426
# [LightGBM] [Info] Start training from score -7.929777
# [LightGBM] [Info] Start training from score -7.275851
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -7.632526
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -5.484091
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.316673
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -6.983181
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -8.143351
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -7.929777
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -6.710537
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -5.794246
# [LightGBM] [Info] Start training from score -5.560253
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -6.733526
# [LightGBM] [Info] Start training from score -7.753887
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.855669
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -6.028818
# [LightGBM] [Info] Start training from score -8.143351
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -5.771773
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -7.722138
# [LightGBM] [Info] Start training from score -7.892037
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -5.951432
# [LightGBM] [Info] Start training from score -8.192141
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -5.385755
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.548816
# [LightGBM] [Info] Start training from score -5.670421
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -3.633015
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -3.852240
# [LightGBM] [Info] Start training from score -7.403684
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -6.644579
# [LightGBM] [Info] Start training from score -6.282599
# [LightGBM] [Info] Start training from score -6.260620
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -5.864864
# [LightGBM] [Info] Start training from score -5.978388
# [LightGBM] [Info] Start training from score -7.296053
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.576956
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -7.028991
# [LightGBM] [Info] Start training from score -5.432132
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.243435
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -7.753887
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.359560
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -5.361874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.576956
# [LightGBM] [Info] Start training from score -6.602906
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -5.135785
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -5.186459
# [LightGBM] [Info] Start training from score -7.722138
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.632526
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.831165
# [LightGBM] [Info] Start training from score -6.769033
# [LightGBM] [Info] Start training from score -4.932124
# [LightGBM] [Info] Start training from score -6.543483
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.316673
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -7.217582
# [LightGBM] [Info] Start training from score -6.897414
# [LightGBM] [Info] Start training from score -6.011724
# [LightGBM] [Info] Start training from score -7.077000
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -7.474302
# [LightGBM] [Info] Start training from score -5.627192
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -3.432535
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.691366
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -4.392168
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -3.585472
# [LightGBM] [Info] Start training from score -7.381211
# [LightGBM] [Info] Start training from score -7.576956
# [LightGBM] [Info] Start training from score -6.666085
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -6.343687
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -3.347954
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -8.548816
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -5.293471
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -5.821898
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -6.305072
# [LightGBM] [Info] Start training from score -7.236630
# [LightGBM] [Info] Start training from score -7.604355
# [LightGBM] [Info] Start training from score -5.869754
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -5.047989
# [LightGBM] [Info] Start training from score -6.998219
# [LightGBM] [Info] Start training from score -6.857140
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.953767
# [LightGBM] [Info] Start training from score -2.950130
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -7.359232
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -7.450204
# [LightGBM] [Info] Start training from score -7.093529
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.892037
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -5.674445
# [LightGBM] [Info] Start training from score -5.018263
# [LightGBM] [Info] Start training from score -7.722138
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -7.144822
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.180541
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -8.143351
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -7.576956
# [LightGBM] [Info] Start training from score -6.710537
# [LightGBM] [Info] Start training from score -8.297502
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.722138
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -7.426674
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -7.576956
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.312676
# [LightGBM] [Info] Start training from score -6.246231
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.710537
# [LightGBM] [Info] Start training from score -7.855669
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -4.597573
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -7.498994
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -5.164426
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -5.678485
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -3.575537
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -5.686616
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -4.601702
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.243435
# [LightGBM] [Info] Start training from score -6.088007
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.381211
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -7.604355
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -7.256048
# [LightGBM] [Info] Start training from score -8.009820
# [LightGBM] [Info] Start training from score -7.127431
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -6.046210
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -7.691366
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -7.550288
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.548816
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -7.060739
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -5.715603
# [LightGBM] [Info] Start training from score -6.408750
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -7.077000
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.633997
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.998219
# [LightGBM] [Info] Start training from score -6.870386
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.243435
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -5.732553
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -7.162522
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -3.016557
# [LightGBM] [Info] Start training from score -6.983181
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.077000
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -6.688064
# [LightGBM] [Info] Start training from score -6.170594
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -6.088007
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -2.813858
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -7.550288
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -7.753887
# [LightGBM] [Info] Start training from score -6.028818
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -5.457774
# [LightGBM] [Info] Start training from score -3.238077
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -7.296053
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -6.870386
# [LightGBM] [Info] Start training from score -6.781155
# [LightGBM] [Info] Start training from score -6.998219
# [LightGBM] [Info] Start training from score -7.060739
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.143351
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -7.450204
# [LightGBM] [Info] Start training from score -6.232047
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -7.217582
# [LightGBM] [Info] Start training from score -6.572753
# [LightGBM] [Info] Start training from score -8.009820
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -6.602906
# [LightGBM] [Info] Start training from score -4.420531
# [LightGBM] [Info] Start training from score -5.367791
# [LightGBM] [Info] Start training from score -5.005789
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -4.298282
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -4.691099
# [LightGBM] [Info] Start training from score -5.978388
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.297502
# [LightGBM] [Info] Start training from score -6.408750
# [LightGBM] [Info] Start training from score -7.381211
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -7.892037
# [LightGBM] [Info] Start training from score -3.276183
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -5.441671
# [LightGBM] [Info] Start training from score -6.144449
# [LightGBM] [Info] Start training from score -7.632526
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -5.245074
# [LightGBM] [Info] Start training from score -7.892037
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.968998
# [LightGBM] [Info] Start training from score -7.474302
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -5.940850
# [LightGBM] [Info] Start training from score -7.524312
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -7.576956
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -7.691366
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -7.180541
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -6.218060
# [LightGBM] [Info] Start training from score -3.381584
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -7.044739
# [LightGBM] [Info] Start training from score -7.028991
# [LightGBM] [Info] Start training from score -5.889556
# [LightGBM] [Info] Start training from score -7.426674
# [LightGBM] [Info] Start training from score -6.602906
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -7.359232
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -7.753887
# [LightGBM] [Info] Start training from score -7.217582
# [LightGBM] [Info] Start training from score -7.604355
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.911208
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.143351
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -7.316673
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.400382
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -7.550288
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -7.632526
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -6.953767
# [LightGBM] [Info] Start training from score -6.699237
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.009820
# [LightGBM] [Info] Start training from score -5.166850
# [LightGBM] [Info] Start training from score -6.328061
# [LightGBM] [Info] Start training from score -6.417189
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -5.528392
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -6.710537
# [LightGBM] [Info] Start training from score -7.929777
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -7.550288
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -5.318577
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -4.091152
# [LightGBM] [Info] Start training from score -8.052380
# [LightGBM] [Info] Start training from score -5.728288
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -7.180541
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.998219
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.553145
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -6.069880
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.870386
# [LightGBM] [Info] Start training from score -8.052380
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -6.818426
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.990649
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -9.396114
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -7.256048
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -6.857140
# [LightGBM] [Info] Start training from score -8.297502
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.699237
# [LightGBM] [Info] Start training from score -9.241964
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -6.312676
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -6.623526
# [LightGBM] [Info] Start training from score -8.096831
# [LightGBM] [Info] Start training from score -6.870386
# [LightGBM] [Info] Start training from score -7.786676
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -6.953767
# [LightGBM] [Info] Start training from score -6.998219
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.722138
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -5.925184
# [LightGBM] [Info] Start training from score -7.820578
# [LightGBM] [Info] Start training from score -7.820578
# [LightGBM] [Info] Start training from score -9.108432
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -7.403684
# [LightGBM] [Info] Start training from score -8.354660
# [LightGBM] [Info] Start training from score -6.253400
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -6.592754
# [LightGBM] [Info] Start training from score -7.661513
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -8.415285
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.052380
# [LightGBM] [Info] Start training from score -8.622924
# [LightGBM] [Info] Start training from score -9.578436
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -5.682542
# [LightGBM] [Info] Start training from score -5.428972
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -7.359232
# [LightGBM] [Info] Start training from score -8.243435
# [LightGBM] [Info] Start training from score -6.131628
# [LightGBM] [Info] Start training from score -8.702967
# [LightGBM] [Info] Start training from score -8.789978
# [LightGBM] [Info] Start training from score -5.438481
# [LightGBM] [Info] Start training from score -3.675256
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -5.373743
# [LightGBM] [Info] Start training from score -8.885289
# [LightGBM] [Info] Start training from score -4.488373
# [LightGBM] [Info] Start training from score -10.089261
# [LightGBM] [Info] Start training from score -6.677014
# [LightGBM] [Info] Start training from score -4.999610
# [LightGBM] [Info] Start training from score -11.187874
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -10.494727
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -6.505743
# [LightGBM] [Info] Start training from score -8.479824
# [LightGBM] [Info] Start training from score -6.983181
# [LightGBM] [Info] Start training from score -5.749794
# [LightGBM] [Info] Start training from score -6.434284
# [LightGBM] [Info] Start training from score -9.801579
# [LightGBM] [Info] Start training from score -5.507701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements

# %%
missing_vals_2 = missing_values_table(df)
missing_vals_2

# df.head()
# Out:
# Your selected dataframe has 25 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
df.head()
# Out:
#                  vin  year        make              model              body  \
# 0  5NPEG4JA8NH134099  2022     Hyundai             Sonata          4D Sedan
# 1  JTDEPMAE5NJ210260  2022      Toyota            Corolla          4D Sedan
# 2  3GCUDFE80RG128481  2024   Chevrolet     Silverado 1500       4D Crew Cab
# 3  1V2WE2CA5PC229115  2023  Volkswagen  Atlas Cross Sport  4D Sport Utility
# 4  58AGZ1B12MU110647  2021       Lexus             ES 350          4D Sedan
#
#             trim  basePrice  mileage    state  averageRating  numberOfReviews  \
# 0             SE      19998    56782  Georgia       4.200000                5
# 1             LE      20998    33730  Georgia       4.500000               22
# 2  LT Trail Boss      51998    58240  Georgia       5.000000                1
# 3      SE w/Tech      32998    15895  Georgia       5.000000                2
# 4        F-Sport      35998    26900  Georgia       4.333333                6
#
#   exteriorColor interiorColor transmission  mpgCity  mpgHighway  cylinders  \
# 0          Gray          Gray    Automatic     28.0        38.0          4
# 1          Blue         Black    Automatic     30.0        38.0          4
# 2         Black         Black    Automatic     23.0        27.0          6
# 3         Black         Black    Automatic     18.0        24.0          6
# 4         Black           Red    Automatic     22.0        31.0          6
#
#           driveTrain engineType  horsepower  horsepowerRpm engineSize  \
# 0  Front Wheel Drive        Gas       191.0         6100.0       2.5L
# 1  Front Wheel Drive        Gas       139.0         6100.0       1.8L
# 2   Four Wheel Drive     Diesel       305.0         3750.0       3.0L
# 3  Front Wheel Drive        Gas       276.0         6200.0       3.6L
# 4  Front Wheel Drive        Gas       302.0         6600.0       3.5L
#
#    engineTorque  engineTorqueRpm  featureScore
# 0         181.0           4000.0           3.0
# 1         126.0           3900.0           7.0
# 2         495.0           2750.0          10.0
# 3         266.0           3600.0           5.0
# 4         267.0           4700.0           7.0
