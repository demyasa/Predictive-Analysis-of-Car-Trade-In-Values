# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)
import glob
import missingno as msno
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read in the Dataset

# %%
# Point to data files location
path = "./scraper/data/6_23_2025/"
all_files = glob.glob(path + "*.json")

# Read all files into single dataframe
df_list = []
for file in all_files:
    df = pd.read_json(file)
    df_list.append(df)

# ignore_index resets index of combined DF to prevent index duplicates
raw_df = pd.concat(df_list, ignore_index=True) 

# Display entire data frame
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Examine and excerpt of data
raw_df.head(5)
# Out:
#    stockNumber                vin  year        make              model  \
# 0     27461478  5NPEG4JA8NH134099  2022     Hyundai             Sonata
# 1     26070459  JTDEPMAE5NJ210260  2022      Toyota            Corolla
# 2     27175122  3GCUDFE80RG128481  2024   Chevrolet     Silverado 1500
# 3     27072297  1V2WE2CA5PC229115  2023  Volkswagen  Atlas Cross Sport
# 4     27386026  58AGZ1B12MU110647  2021       Lexus             ES 350
#
#                body           trim  basePrice  originalPrice  hasPriceDrop  \
# 0          4D Sedan             SE      19998            NaN         False
# 1          4D Sedan             LE      20998            NaN         False
# 2       4D Crew Cab  LT Trail Boss      51998            NaN         False
# 3  4D Sport Utility      SE w/Tech      32998            NaN         False
# 4          4D Sedan        F-Sport      35998            NaN         False
#
#    mileage  storeId storeName storeCity    state stateAbbreviation  distance  \
# 0    56782     7298   Roswell   Roswell  Georgia                GA    2108.0
# 1    33730     7298   Roswell   Roswell  Georgia                GA    2108.0
# 2    58240     7298   Roswell   Roswell  Georgia                GA    2108.0
# 3    15895     7298   Roswell   Roswell  Georgia                GA    2108.0
# 4    26900     7298   Roswell   Roswell  Georgia                GA    2108.0
#
#    averageRating  numberOfReviews  repairPalData  isNewArrival  \
# 0       4.200000                5            NaN         False
# 1       4.500000               22            NaN         False
# 2       5.000000                1            NaN         False
# 3       5.000000                2            NaN         False
# 4       4.333333                6            NaN         False
#
#    isTransferable                                           features  \
# 0            True  [Rear Defroster, Overhead Airbags, Auxiliary A...
# 1            True  [Power Windows, Power Locks, Air Conditioning,...
# 2            True  [Power Locks, Auxiliary Audio Input, AM/FM Ste...
# 3            True  [Alloy Wheels, 20 Inch Plus Wheels, Power Lock...
# 4            True  [Power Windows, Traction Control, ABS Brakes, ...
#
#                                  highlightedFeatures  \
# 0  Rear View Camera,Auxiliary Audio Input,Alloy W...
# 1  Rear View Camera,Auxiliary Audio Input,Overhea...
# 2  Z71 Package,4WD/AWD,Leather Seats,BOSE Sound S...
# 3  Technology Package,Leatherette Seats,Satellite...
# 4  Leatherette Seats,Pioneer Sound System,Parking...
#
#                                           highlights  \
# 0  [singleOwner, warranty, fuelEfficient, advance...
# 1        [warranty, fuelEfficient, advancedFeatures]
# 2      [singleOwner, advancedFeatures, premiumAudio]
# 3  [singleOwner, lowMiles, warranty, advancedFeat...
# 4  [singleOwner, lowMilesPerYear, warranty, advan...
#
#        lastMadeSaleableDate  transferFee            transferTags  \
# 0  2025-06-12T20:56:13.565Z       1999.0  [GeneratedByCps, Paid]
# 1  2025-06-12T20:53:33.311Z       1999.0  [GeneratedByCps, Paid]
# 2  2025-06-20T21:39:32.178Z       1999.0  [GeneratedByCps, Paid]
# 3  2025-05-28T20:50:22.353Z       1999.0  [GeneratedByCps, Paid]
# 4   2025-06-13T20:59:37.45Z       1999.0  [GeneratedByCps, Paid]
#
#      transferText   transferType  minEstimatedTransferDurationInDays  \
# 0  $1999 Shipping  shipping-from                                 9.0
# 1  $1999 Shipping  shipping-from                                 9.0
# 2  $1999 Shipping  shipping-from                                 9.0
# 3  $1999 Shipping  shipping-from                                 9.0
# 4  $1999 Shipping  shipping-from                                 9.0
#
#    maxEstimatedTransferDurationInDays  transferTimesUnavailable exteriorColor  \
# 0                                22.0                     False          Gray
# 1                                22.0                     False          Blue
# 2                                22.0                     False         Black
# 3                                22.0                     False         Black
# 4                                22.0                     False         Black
#
#   interiorColor  normalizedExteriorColor  normalizedInteriorColor  \
# 0          Gray                      NaN                      NaN
# 1         Black                      NaN                      NaN
# 2         Black                      NaN                      NaN
# 3         Black                      NaN                      NaN
# 4           Red                      NaN                      NaN
#
#   transmission  review  numberOfFavorites  isSaleable  isComingSoon  \
# 0    Automatic     NaN                  0        True         False
# 1    Automatic     NaN                  0        True         False
# 2    Automatic     NaN                  0        True         False
# 3    Automatic     NaN                  0        True         False
# 4    Automatic     NaN                  0        True         False
#
#    isReserved  mpgCity  mpgHighway  originalBatteryRangeInMiles  cylinders  \
# 0       False     28.0        38.0                          NaN          4
# 1       False     30.0        38.0                          NaN          4
# 2       False     23.0        27.0                          NaN          6
# 3       False     18.0        24.0                          NaN          6
# 4       False     22.0        31.0                          NaN          6
#
#           driveTrain engineType  fuelType  horsepower  horsepowerRpm  \
# 0  Front Wheel Drive        Gas       NaN       191.0         6100.0
# 1  Front Wheel Drive        Gas       NaN       139.0         6100.0
# 2   Four Wheel Drive     Diesel       NaN       305.0         3750.0
# 3  Front Wheel Drive        Gas       NaN       276.0         6200.0
# 4  Front Wheel Drive        Gas       NaN       302.0         6600.0
#
#   engineSize  engineTorque  engineTorqueRpm  \
# 0       2.5L         181.0           4000.0
# 1       1.8L         126.0           3900.0
# 2       3.0L         495.0           2750.0
# 3       3.6L         266.0           3600.0
# 4       3.5L         267.0           4700.0
#
#                                 priorUseDescriptions  isAvailableToTransact  \
# 0  [{'id': 20, 'name': 'Leased Vehicle', 'descrip...                   True
# 1  [{'id': 10, 'name': 'Fleet', 'description': 'T...                   True
# 2                                                 []                   True
# 3  [{'id': 10, 'name': 'Fleet', 'description': 'T...                   True
# 4  [{'id': 20, 'name': 'Leased Vehicle', 'descrip...                   True
#
#    recommendationType  bestFinanceDecision  \
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
#                                                store  featureScore  \
# 0  {'id': 7298, 'name': 'Roswell', 'city': None, ...           3.0
# 1  {'id': 7298, 'name': 'Roswell', 'city': None, ...           7.0
# 2  {'id': 7298, 'name': 'Roswell', 'city': None, ...          10.0
# 3  {'id': 7298, 'name': 'Roswell', 'city': None, ...           5.0
# 4  {'id': 7298, 'name': 'Roswell', 'city': None, ...           7.0
#
#    vehicleSize                            packages  types series  isSavedCar  \
# 0          NaN                                  []    NaN   None       False
# 1          NaN                                  []    NaN   None       False
# 2          NaN  [Convenience Package, Z71 Package]    NaN   None       False
# 3          NaN                [Technology Package]    NaN   None       False
# 4          NaN                                  []    NaN     ES       False
#
#                                         heroImageUrl  heroThumbnailImageUrl  \
# 0  https://img2.carmax.com/assets/27461478/hero.j...                    NaN
# 1  https://img2.carmax.com/assets/26070459/hero.j...                    NaN
# 2  https://img2.carmax.com/assets/27175122/hero.j...                    NaN
# 3  https://img2.carmax.com/assets/27072297/hero.j...                    NaN
# 4  https://img2.carmax.com/assets/27386026/hero.j...                    NaN
#
#    isEVTaxCreditEligible
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %% [markdown]
# ### Drop Duplicate Rows

# %%
# Make a copy of the original dataframe
df = raw_df.copy()

# Check rows with duplicate VINS and drop
df = df.drop_duplicates(subset=['vin'], keep='first')

# %% [markdown]
# ### Convert Engine Size to Numeric Datatype

# %%
# Convert Engine Size into a numeric feature by removing the L and changing datatype
df['engineSize'] = df['engineSize'].str.replace('L', '', regex=False)
df['engineSize'] = pd.to_numeric(df['engineSize'])

print(df['engineSize'].dtype)
# Out:
# float64

# %% [markdown]
# ### Drop Outliers in Mileage column (only one)

# %%
# Remove all outliers in the mileage column based on a zscore of 3
df = df[np.abs(stats.zscore(df['mileage'])) < 3]

print("DataFrame Shape After:", df.shape)
# Out:
# DataFrame Shape After: (86159, 69)

# %% [markdown]
# ### Remove Unnecessary Columns Based on Previous Analyses

# %%
# Store irrelevant features into an array
irrelevant_features = [
    'stockNumber', 'hasPriceDrop', 'distance', 'isNewArrival',
    'isTransferable', 'lastMadeSaleableDate', 'transferFee', 'transferTags',
    'transferText', 'transferType', 'minEstimatedTransferDurationInDays', 'maxEstimatedTransferDurationInDays',
    'transferTimesUnavailable', 'isSaleable', 'isComingSoon', 'isReserved',
    'isAvailableToTransact', 'recommendationType', 'bestFinanceDecision', 'isSavedCar',  'isEVTaxCreditEligible', 'numberOfFavorites',
    'heroImageUrl', 'heroThumbnailImageUrl'
]

# Leave only state to represent location
location_features = [
    'store', 'storeId', 'storeName', 'storeCity', 'stateAbbreviation'
]

# Remove missing values features (over 90% missing values)
missing_value_features = [
    'review', 'repairPalData', 'types', 'vehicleSize', 
    'normalizedExteriorColor', 'normalizedInteriorColor', 'fuelType',
    'originalBatteryRangeInMiles', 'originalPrice', 'series'
]

# Drop features being analyzed in a different file
complex_features = [
    'features', 'highlightedFeatures', 'highlights',
    'priorUseDescriptions', 'packages'
]

# Drop features responsible for multicollinearity
collinear_features = [
    'engineSize', 'horsepower'
]

# Drop irrelevant feature arrays defined above
df = df.drop(columns = irrelevant_features, axis = 1)
df = df.drop(columns = location_features, axis = 1)
df = df.drop(columns = missing_value_features, axis = 1)
df = df.drop(columns = complex_features, axis = 1)
df = df.drop(columns = collinear_features, axis = 1)

# Remove missing value rows for the following features
missing_value_rows = [
    'interiorColor', 'exteriorColor'
]
df.dropna(subset=missing_value_rows, how='any',inplace=True)

print("DataFrame Shape:", df.shape)
# Out:
# DataFrame Shape: (86025, 23)

# %% [markdown]
# ### Create mpg Feature using mpgHighway and mpgCity
#
# The Combined MPG value is the most prominent for the purpose of quick and easy comparison across vehicles. Combined fuel economy is a weighted average of City and Highway MPG values that is calculated by weighting the City value by 55% and the Highway value by 45%.

# %%
# Assign weights based on US EPA recommendation
highwayWeight = 0.45
cityWeight = 0.55

# Create new feature
df['mpg'] = (df['mpgHighway'] * highwayWeight) + (df['mpgCity'] * cityWeight)

# Drop old features
df = df.drop(columns = ['mpgHighway', 'mpgCity'], axis = 1)

df.head()
# Out:
#                  vin  year        make              model              body  \
# 0  5NPEG4JA8NH134099  2022     Hyundai             Sonata          4D Sedan
# 1  JTDEPMAE5NJ210260  2022      Toyota            Corolla          4D Sedan
# 2  3GCUDFE80RG128481  2024   Chevrolet     Silverado 1500       4D Crew Cab
# 3  1V2WE2CA5PC229115  2023  Volkswagen  Atlas Cross Sport  4D Sport Utility
# 4  58AGZ1B12MU110647  2021       Lexus             ES 350          4D Sedan
#
#             trim  basePrice  mileage    state  averageRating  numberOfReviews  \
# 0             SE      19998    56782  Georgia       4.200000                5
# 1             LE      20998    33730  Georgia       4.500000               22
# 2  LT Trail Boss      51998    58240  Georgia       5.000000                1
# 3      SE w/Tech      32998    15895  Georgia       5.000000                2
# 4        F-Sport      35998    26900  Georgia       4.333333                6
#
#   exteriorColor interiorColor transmission  cylinders         driveTrain  \
# 0          Gray          Gray    Automatic          4  Front Wheel Drive
# 1          Blue         Black    Automatic          4  Front Wheel Drive
# 2         Black         Black    Automatic          6   Four Wheel Drive
# 3         Black         Black    Automatic          6  Front Wheel Drive
# 4         Black           Red    Automatic          6  Front Wheel Drive
#
#   engineType  horsepowerRpm  engineTorque  engineTorqueRpm  featureScore  \
# 0        Gas         6100.0         181.0           4000.0           3.0
# 1        Gas         6100.0         126.0           3900.0           7.0
# 2     Diesel         3750.0         495.0           2750.0          10.0
# 3        Gas         6200.0         266.0           3600.0           5.0
# 4        Gas         6600.0         267.0           4700.0           7.0
#
#      mpg
# 0  32.50
# 1  33.60
# 2  24.80
# 3  20.70
# 4  26.05

# %% [markdown]
# ### Check Remaining Missing Values

# %%
# Use method to display a list of missing values and their percentages

# credit: https://www.kaggle.com/willkoehrsen/start-here-a-gentle-introduction. 

def missing_values_table(df):
    # Total missing values
    mis_val = df.isnull().sum()
    
    # Percentage of missing values
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    
    # Make a table with the results
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    
    # Rename the columns
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    
    # Sort the table by percentage of missing descending
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(2)
    
    # Print some summary information
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    
    # Return the dataframe with missing information
    return mis_val_table_ren_columns

# %%
# Apply missing values table method on the dataframe
missing_vals = missing_values_table(df)
missing_vals
# Out:
# Your selected dataframe has 22 columns.
# There are 9 columns that have missing values.
#                  Missing Values  % of Total Values
# featureScore               8760              10.18
# trim                       7344               8.54
# engineTorqueRpm            5838               6.79
# horsepowerRpm              5070               5.89
# engineTorque               4542               5.28
# mpg                        3442               4.00
# driveTrain                  264               0.31
# engineType                    2               0.00
# body                          1               0.00

# %% [markdown]
# ### Impute Missing Values

# %%
# Regressor for Numerical Values
# Classifier for Categorical Values
from lightgbm import LGBMRegressor, LGBMClassifier

# %%
# Display columns in df with missing vals
cols_with_nans = [x for x in df if df[x].isnull().sum() > 0]
cols_with_nans
# Out:
# ['body',
#  'trim',
#  'driveTrain',
#  'engineType',
#  'horsepowerRpm',
#  'engineTorque',
#  'engineTorqueRpm',
#  'featureScore',
#  'mpg']

# %%
# Divide into categorical and numeric columns
num_cols = [col for col in df[cols_with_nans].select_dtypes(exclude='O')]
cat_cols = [col for col in df[cols_with_nans].select_dtypes(include='O')]

print("Numeric Columns: \n", num_cols)
print("Categorical Columns: \n", cat_cols)
# Out:
# Numeric Columns:
#  ['horsepowerRpm', 'engineTorque', 'engineTorqueRpm', 'featureScore', 'mpg']
# Categorical Columns:
#  ['body', 'trim', 'driveTrain', 'engineType']

# %%
def factorize(data):
    # Factorize categorical data so its represented as integers
    for cat_col in data.select_dtypes(include='O'):
        data[cat_col] = pd.factorize(data[cat_col])[0]
    return data

def create_splits(data, col):
    # Train Test split on null values present
    train = data[data['is_nan'] == 0]
    test = data[data['is_nan'] == 1]
    X_train = train.drop([col, 'is_nan'], axis=1)
    y_train = train[col]
    X_test = test.drop([col, 'is_nan'], axis=1)
    return X_train, y_train, X_test

def train_predict(mode, X_train, y_train, X_test):
    if mode == 'regression':
        model = LGBMRegressor()
    else :
        model = LGBMClassifier()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return y_pred


def impute_missing(df, col_list, mode):
    for col in col_list:
        print("Column Examined: ", col)
        if df[col].isnull().sum() > int(len(df)/2):
            df.drop(col, axis=1, inplace=True)
            print(f'Dropped {col} because it had over 50% missing values')
        else:
            data = df.copy()
            # Reset Indexes
            data = data.reset_index(drop=True)
            nan_ixs = np.where(data[col].isna())[0]
            data['is_nan'] = 0
            data.loc[nan_ixs, 'is_nan'] = 1
            X = data.drop([col], axis=1)
            y = data[col]
            X = factorize(X)
            data = X.join(y)
            X_train, y_train, X_test = create_splits(data, col)
            y_pred = train_predict(mode, X_train, y_train, X_test)
            # If prediction is numeric then round it
            if y_pred.dtype == 'float64':
                y_pred = np.round(y_pred)
            print("Predictions: \n", y_pred)
            # Include predicted values in the indices of missing column
            df = df.reset_index(drop=True)
            df.loc[nan_ixs, col] = y_pred
            # df = data
    return df

df = impute_missing(df, num_cols, 'regression')
df = impute_missing(df, cat_cols, 'classification')
# Out:
# Column Examined:  horsepowerRpm
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001482 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2110
# [LightGBM] [Info] Number of data points in the train set: 80955, number of used features: 21
# [LightGBM] [Info] Start training from score 5870.812859
# Predictions:
#  [6122. 5880. 5639. ... 6063. 5656. 5874.]
# Column Examined:  engineTorque
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001360 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2070
# [LightGBM] [Info] Number of data points in the train set: 81483, number of used features: 21
# [LightGBM] [Info] Start training from score 235.179461
# Predictions:
#  [416. 351. 203. ... 246. 398. 213.]
# Column Examined:  engineTorqueRpm
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001855 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2109
# [LightGBM] [Info] Number of data points in the train set: 80187, number of used features: 21
# [LightGBM] [Info] Start training from score 3443.391198
# Predictions:
#  [3160. 2230. 2028. ... 1452. 3878. 2492.]
# Column Examined:  featureScore
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001168 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2512
# [LightGBM] [Info] Number of data points in the train set: 77265, number of used features: 21
# [LightGBM] [Info] Start training from score 6.729813
# Predictions:
#  [4. 5. 4. ... 7. 7. 7.]
# Column Examined:  mpg
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001177 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2232
# [LightGBM] [Info] Number of data points in the train set: 82583, number of used features: 21
# [LightGBM] [Info] Start training from score 26.456416
# Predictions:
#  [47. 30. 42. ... 45. 30. 27.]
# Column Examined:  body
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001512 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2513
# [LightGBM] [Info] Number of data points in the train set: 86024, number of used features: 21
# [LightGBM] [Info] Start training from score -4.593888
# [LightGBM] [Info] Start training from score -3.882517
# [LightGBM] [Info] Start training from score -9.752944
# [LightGBM] [Info] Start training from score -5.724027
# [LightGBM] [Info] Start training from score -6.180598
# [LightGBM] [Info] Start training from score -5.924302
# [LightGBM] [Info] Start training from score -8.226887
# [LightGBM] [Info] Start training from score -7.142874
# [LightGBM] [Info] Start training from score -7.219247
# [LightGBM] [Info] Start training from score -8.417943
# [LightGBM] [Info] Start training from score -7.865874
# [LightGBM] [Info] Start training from score -8.964486
# [LightGBM] [Info] Start training from score -7.512234
# [LightGBM] [Info] Start training from score -2.555808
# [LightGBM] [Info] Start training from score -4.331524
# [LightGBM] [Info] Start training from score -9.059797
# [LightGBM] [Info] Start training from score -3.363710
# [LightGBM] [Info] Start training from score -5.403957
# [LightGBM] [Info] Start training from score -4.235491
# [LightGBM] [Info] Start training from score -1.500081
# [LightGBM] [Info] Start training from score -0.553139
# [LightGBM] [Info] Start training from score -4.171706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Predictions:
#  ['4D Crew Cab']
# Column Examined:  trim
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001602 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2270
# [LightGBM] [Info] Number of data points in the train set: 78681, number of used features: 21
# [LightGBM] [Info] Start training from score -8.182115
# [LightGBM] [Info] Start training from score -6.554658
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -8.500568
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -7.212714
# [LightGBM] [Info] Start training from score -8.565107
# [LightGBM] [Info] Start training from score -5.228152
# [LightGBM] [Info] Start training from score -7.114274
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -8.634100
# [LightGBM] [Info] Start training from score -8.565107
# [LightGBM] [Info] Start training from score -7.535487
# [LightGBM] [Info] Start training from score -8.875262
# [LightGBM] [Info] Start training from score -8.565107
# [LightGBM] [Info] Start training from score -6.269211
# [LightGBM] [Info] Start training from score -8.970572
# [LightGBM] [Info] Start training from score -7.905861
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -6.955669
# [LightGBM] [Info] Start training from score -5.775989
# [LightGBM] [Info] Start training from score -8.382785
# [LightGBM] [Info] Start training from score -6.502472
# [LightGBM] [Info] Start training from score -6.628766
# [LightGBM] [Info] Start training from score -6.269211
# [LightGBM] [Info] Start training from score -7.212714
# [LightGBM] [Info] Start training from score -8.634100
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -8.137663
# [LightGBM] [Info] Start training from score -7.871960
# [LightGBM] [Info] Start training from score -8.015060
# [LightGBM] [Info] Start training from score -6.510983
# [LightGBM] [Info] Start training from score -5.796693
# [LightGBM] [Info] Start training from score -5.474064
# [LightGBM] [Info] Start training from score -8.277425
# [LightGBM] [Info] Start training from score -6.878708
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -8.182115
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -5.678446
# [LightGBM] [Info] Start training from score -7.717809
# [LightGBM] [Info] Start training from score -7.940952
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.634100
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -8.500568
# [LightGBM] [Info] Start training from score -8.439944
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.970572
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -7.381337
# [LightGBM] [Info] Start training from score -8.228635
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -7.807421
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -8.788250
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -8.228635
# [LightGBM] [Info] Start training from score -7.423009
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -6.762297
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -6.519567
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.228635
# [LightGBM] [Info] Start training from score -7.230106
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -6.903709
# [LightGBM] [Info] Start training from score -7.940952
# [LightGBM] [Info] Start training from score -7.284173
# [LightGBM] [Info] Start training from score -8.182115
# [LightGBM] [Info] Start training from score -7.511957
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -8.634100
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -5.562730
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -8.500568
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -7.302865
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -7.068464
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -8.228635
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -8.015060
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -6.784521
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -5.879529
# [LightGBM] [Info] Start training from score -5.376003
# [LightGBM] [Info] Start training from score -8.970572
# [LightGBM] [Info] Start training from score -6.807249
# [LightGBM] [Info] Start training from score -7.511957
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -7.381337
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.439944
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -6.042048
# [LightGBM] [Info] Start training from score -8.228635
# [LightGBM] [Info] Start training from score -8.875262
# [LightGBM] [Info] Start training from score -5.767825
# [LightGBM] [Info] Start training from score -8.439944
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -8.182115
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -7.807421
# [LightGBM] [Info] Start training from score -7.977320
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -5.861511
# [LightGBM] [Info] Start training from score -7.535487
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -5.216373
# [LightGBM] [Info] Start training from score -7.662239
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -8.382785
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.634100
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -5.751696
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -3.683315
# [LightGBM] [Info] Start training from score -8.137663
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -3.926502
# [LightGBM] [Info] Start training from score -7.488967
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -6.688190
# [LightGBM] [Info] Start training from score -6.367882
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -6.296423
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -5.930823
# [LightGBM] [Info] Start training from score -6.047410
# [LightGBM] [Info] Start training from score -7.381337
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -7.662239
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -7.098770
# [LightGBM] [Info] Start training from score -5.468022
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -8.328718
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -8.970572
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -7.839170
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -6.444843
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.075932
# [LightGBM] [Info] Start training from score -5.384279
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -7.423009
# [LightGBM] [Info] Start training from score -6.688190
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -5.207049
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -8.565107
# [LightGBM] [Info] Start training from score -8.565107
# [LightGBM] [Info] Start training from score -8.708208
# [LightGBM] [Info] Start training from score -10.174545
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -8.970572
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -5.175083
# [LightGBM] [Info] Start training from score -7.807421
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -7.535487
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -10.580010
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -9.481398
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -8.970572
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -6.854316
# [LightGBM] [Info] Start training from score -6.452875
# [LightGBM] [Info] Start training from score -5.005956
# [LightGBM] [Info] Start training from score -6.563627
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -7.401956
# [LightGBM] [Info] Start training from score -9.327247
# [LightGBM] [Info] Start training from score -7.302865
# [LightGBM] [Info] Start training from score -6.982698
# [LightGBM] [Info] Start training from score -6.074660
# [LightGBM] [Info] Start training from score -7.130022
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -8.788250
# [LightGBM] [Info] Start training from score -9.193715
# [LightGBM] [Info] Start training from score -8.054281
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -7.230106
# [LightGBM] [Info] Start training from score -5.712475
# [LightGBM] [Info] Start training from score -9.663719
# [LightGBM] [Info] Start training from score -8.788250
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -11.273157
# [LightGBM] [Info] Start training from score -3.497042
# [LightGBM] [Info] Start training from score -9.886863
# [LightGBM] [Info] Start training from score -11.273157
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Predictions:
#  ['S' 'S' 'Touring' ... 'S' 'SE' 'SE']
# Column Examined:  driveTrain
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001025 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2526
# [LightGBM] [Info] Number of data points in the train set: 85761, number of used features: 21
# [LightGBM] [Info] Start training from score -1.104542
# [LightGBM] [Info] Start training from score -1.984313
# [LightGBM] [Info] Start training from score -0.850424
# [LightGBM] [Info] Start training from score -2.264053
# Predictions:
#  ['Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Rear Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Rear Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Rear Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Rear Wheel Drive'
#  'Rear Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Rear Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Rear Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'All Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Rear Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Rear Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Four Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'All Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'All Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'Front Wheel Drive'
#  'Front Wheel Drive' 'Front Wheel Drive' 'All Wheel Drive']
# Column Examined:  engineType
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001383 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2528
# [LightGBM] [Info] Number of data points in the train set: 86023, number of used features: 21
# [LightGBM] [Info] Start training from score -4.907171
# [LightGBM] [Info] Start training from score -3.701314
# [LightGBM] [Info] Start training from score -0.088044
# [LightGBM] [Info] Start training from score -3.251642
# [LightGBM] [Info] Start training from score -4.306195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Predictions:
#  ['Gas' 'Gas']

# %%
missing_vals_2 = missing_values_table(df)
missing_vals_2

# df.head()
# Out:
# Your selected dataframe has 22 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
df.to_csv('imputed_data_full.csv', index=False)
df.to_json('imputed_data_full.json', index=False)

# %% [markdown]
# ### Calculate Variance Inflation Factor (VIF)

# %%
# Import VIF packages
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
# Create numeric df
numeric_df_full = df.select_dtypes(include='number')

# Add constant in order to run VIF
num_df_con_full = add_constant(numeric_df_full)

# Remove missing values
num_df_con_full = num_df_con_full.copy().dropna()

# %%
# Create a DataFrame to store VIF values
vif_data_full = pd.DataFrame()
vif_data_full['Feature'] = num_df_con_full.columns
vif_data_full['VIF'] = [variance_inflation_factor(num_df_con_full.values, i) for i in range(num_df_con_full.shape[1])]
vif_data_full = vif_data_full.round(2)
print("DataFrame Shape:", num_df_con_full.shape)
print(vif_data_full)
# Out:
# DataFrame Shape: (86025, 12)
#             Feature         VIF
# 0             const  1318929.14
# 1              year        2.81
# 2         basePrice        4.17
# 3           mileage        2.34
# 4     averageRating        1.14
# 5   numberOfReviews        1.62
# 6         cylinders        2.34
# 7     horsepowerRpm        1.97
# 8      engineTorque        3.54
# 9   engineTorqueRpm        2.12
# 10     featureScore        1.24
# 11              mpg        2.19

# %% [markdown]
# ### Check Correlation Matrix

# %%
# Select numeric datatypes form the dataset
correlation_matrix = df.select_dtypes(include='number').corr()

# Create heatmap
plt.figure(figsize=(8, 6)) # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### Check Random Forest Feature Importance on both
# ### Check difference in model predictions on both
